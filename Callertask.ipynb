# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("/content/drive/MyDrive/test.xlsx")

# %%
data.columns
# Out:
# Index(['call_date', 'status', 'user', 'campaign_id', 'vendor_lead_code',
#        'source_id', 'list_id', 'gmt_offset_now', 'phone_code', 'title',
#        'first_name', 'middle_initial', 'last_name', 'city', 'state',
#        'province', 'postal_code', 'country_code', 'gender', 'date_of_birth',
#        'alt_phone', 'security_phrase', 'length_in_sec', 'user_group',
#        'alt_dial', 'rank', 'owner', 'lead_id', 'list_name', 'list_description',
#        'status_name'],
#       dtype='object')

# %%
data.gender
# Out:
# 0        F
# 1        U
# 2        U
# 3        U
# 4        U
#         ..
# 63551    U
# 63552    U
# 63553    U
# 63554    U
# 63555    U
# Name: gender, Length: 63556, dtype: object

# %%
data.list_name
# Out:
# 0           Transfer API DATA
# 1           Transfer API DATA
# 2           Transfer API DATA
# 3           Transfer API DATA
# 4           Transfer API DATA
#                  ...
# 63551       Transfer API DATA
# 63552          work8 fronters
# 63553       Transfer API DATA
# 63554    Default inbound list
# 63555    Default inbound list
# Name: list_name, Length: 63556, dtype: object

# %%
data.status_name
# Out:
# 0                  Call Back
# 1          Answering Machine
# 2                    Hang Up
# 3          Answering Machine
# 4          Answering Machine
#                 ...
# 63551          Sch Call Back
# 63552         Not Interested
# 63553    Agent Not Available
# 63554    Agent Not Available
# 63555    Agent Not Available
# Name: status_name, Length: 63556, dtype: object

# %%
x=data['list_name']
y=data['status_name']

# %%
currentgp=data.loc[data['gender']=='F']
x=currentgp['list_name']
y=currentgp['status_name']
plt.xlabel('list_id',fontsize=18)
plt.ylabel('status_name',fontsize=16)
plt.bar(x,y)
plt.show()

# %%
#CURRENT USER GROUP FOR DStorm
currentgp=data.loc[data['gender']=='M']
x=currentgp['list_name']
y=currentgp['status_name']
plt.xlabel('list_name',fontsize=18)
plt.ylabel('status_name',fontsize=16)
plt.bar(x,y)
plt.show()
